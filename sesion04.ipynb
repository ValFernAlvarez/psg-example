# %%
# Code 01
#print("Hola Mundo desde Notebook.")
print("     (           )")
print("   (              )")
print("  (                 )")
print("   (              )")
print("        1    1")
print("        1    1")
print("        1    1")
print("      ^^^^^^^^^")
# Out:
#      (           )
#    (              )
#   (                 )
#    (              )
#         1    1
#         1    1
#         1    1
#       ^^^^^^^^^

# %% [markdown]
# # Sesión 04
# - Mi primer notebook
# - Imprimir árbol
# - Crear Markdown
# - Subir a mi repositorio de GitHub
